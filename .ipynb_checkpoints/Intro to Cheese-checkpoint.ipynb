# %%
def cheese_finder():
    import requests
    import json
    url = 'https://api.nal.usda.gov/ndb/reports/?ndbno=01009&type=b&format=json&api_key=DEMO_KEY'
    #url ='https://ndb.nal.usda.gov/ndb/nutrients/report/nutrientsfrm?max=308&offset=0&totCount=0&nutrient1=255&nutrient2=268&nutrient3=&fg=21&subset=0&sort=c&measureby=g&format=json&api_key=etJJrPumUIJwpjq4L82CX2c7Dh8XW2Bt8IGPcbJe'
    response = requests.get(url)
    cheeses = response.json()
    report = cheeses['report']
    food = report['food']
    nutrients = food['nutrients']
    return nutrients

# %%
cheese_finder()
# Out:
# [{'nutrient_id': '255',
#   'name': 'Water',
#   'derivation': 'NONE',
#   'group': 'Proximates',
#   'unit': 'g',
#   'value': '36.75',
#   'measures': [{'label': 'cup, diced',
#     'eqv': 132.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '48.51'},
#    {'label': 'cup, melted',
#     'eqv': 244.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '89.67'},
#    {'label': 'cup, shredded',
#     'eqv': 113.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '41.53'},
#    {'label': 'oz', 'eqv': 28.35, 'eunit': 'g', 'qty': 1.0, 'value': '10.42'},
#    {'label': 'cubic inch',
#     'eqv': 17.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '6.25'},
#    {'label': 'slice (1 oz)',
#     'eqv': 28.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '10.29'}]},
#  {'nutrient_id': '208',
#   'name': 'Energy',
#   'derivation': 'NC',
#   'group': 'Proximates',
#   'unit': 'kcal',
#   'value': '403',
#   'measures': [{'label': 'cup, diced',
#     'eqv': 132.0,
# ...

# %%
incheese = print(input("Enter name of cheese (options are: diced, melted, shredded, oz, cubic inch, or slice): "))
# Out:
# Enter name of cheese (options are: diced, melted, shredded, oz, cubic inch, or slice): diced
# diced

# %%
if incheese in cheese_finder:
    print(cheese['nutrients'])
else:
    print("Cheese if not listed try again")
return
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-518537b8ae57> in <module>()
# ----> 1 if incheese in cheese_finder:
#       2     print(cheese['nutrients'])
#       3 else:
#       4     print("Cheese if not listed try again")
#       5 return
#
# TypeError: argument of type 'function' is not iterable

# %%
recommendation = print(input("Do you want a recommendation?"))

# %%
while recommendation == "yes" or "Yes" or "y" or "YES" or "YeS" or "yES" or "Yesss" or "Yes!!!":
    if incheese in cheese_finder:
    print(cheese['nutrients'])
    else:
    print("Cheese if not listed try again")
    return
break
# Out:
#   File "<ipython-input-8-9cfd187e7cfa>", line 3
#     print(cheese['nutrients'])
#         ^
# IndentationError: expected an indented block
